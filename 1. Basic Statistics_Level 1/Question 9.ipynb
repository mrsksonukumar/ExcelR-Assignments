# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statistics
# %matplotlib inline

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is FEA4-9C8F
#
#  Directory of C:\Users\mrsks\OneDrive\Desktop\Data Science - Somnath\Assignments - Final
#
# 26-06-2022  21:42    <DIR>          .
# 26-06-2022  18:32    <DIR>          ..
# 26-06-2022  21:41    <DIR>          .ipynb_checkpoints
# 26-06-2022  20:52            50,147 Assignment - 1.docx
# 26-06-2022  18:34               962 Q7.csv
# 26-06-2022  21:41               502 Q9_a.csv
# 26-06-2022  21:41                72 Question 9.ipynb
# 26-06-2022  21:40            34,037 Question Seven.ipynb
#                5 File(s)         85,720 bytes
#                3 Dir(s)  440,406,593,536 bytes free

# %%
q9=pd.read_csv("Q9_a.csv")
q9
# Out:
#     Index  speed  dist
# 0       1      4     2
# 1       2      4    10
# 2       3      7     4
# 3       4      7    22
# 4       5      8    16
# 5       6      9    10
# 6       7     10    18
# 7       8     10    26
# 8       9     10    34
# 9      10     11    17
# 10     11     11    28
# 11     12     12    14
# 12     13     12    20
# 13     14     12    24
# 14     15     12    28
# 15     16     13    26
# 16     17     13    34
# 17     18     13    34
# 18     19     13    46
# 19     20     14    26
# 20     21     14    36
# 21     22     14    60
# 22     23     14    80
# 23     24     15    20
# 24     25     15    26
# 25     26     15    54
# 26     27     16    32
# 27     28     16    40
# 28     29     17    32
# 29     30     17    40
# 30     31     17    50
# 31     32     18    42
# 32     33     18    56
# 33     34     18    76
# 34     35     18    84
# 35     36     19    36
# 36     37     19    46
# 37     38     19    68
# 38     39     20    32
# ...

# %% [markdown]
# # Skewness

# %%
q9.skew(axis=0)
# Out:
# Index    0.000000
# speed   -0.117510
# dist     0.806895
# dtype: float64

# %% [markdown]
# # Kurtosis

# %%
q9.kurtosis(axis=0)
# Out:
# Index   -1.200000
# speed   -0.508994
# dist     0.405053
# dtype: float64

# %% [markdown]
# # Inferences on the following data Speed and Distance

# %%
f,ax=plt.subplots(figsize=(15,5))
plt.subplot(1,3,1)
plt.boxplot(q9.speed)
plt.title('speed')
plt.subplot(1,3,2)
plt.boxplot(q9.dist)
plt.title('dist')
plt.show()
